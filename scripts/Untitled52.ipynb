# %%
import pandas as pd

# %%
df = pd.read_excel("/content/MBU_Entry_Status_District_Wise 15-07-2026 12-10-17 PM.xlsx", sheet_name='MBU_Entry_Status_District_Wise')
# Out:
# /usr/local/lib/python3.12/dist-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
df.columns = df.iloc[2].values

# %%
df = df.iloc[4:]

# %%
df = df[df['Academic Year'] == '2026-27']

# %%
df.head()
# Out:
#    District Name District Code Academic Year Total Student  \
# 5          BALOD          2222       2026-27        124282
# 7    BALODABAZAR          2224       2026-27        215368
# 9      BALRAMPUR          2226       2026-27        152725
# 11        BASTER          2215       2026-27        145538
# 13      BEMETARA          2223       2026-27        158754
#
#    Total Students AADHAAR Provided AADHAAR Verified-Passed(Yes)  \
# 5                           123608                       115650
# 7                           211289                       201670
# 9                           139275                       124011
# 11                          136475                       123715
# 13                          156635                       152298
#
#    AADHAAR Verified-Failed(No) AADHAAR Verified-To be Done  \
# 5                         7573                         385
# 7                         8873                         746
# ...

# %%
x = ((df['Status Check to be done'] + df['MBU Not Required']) / df['Total Student'])*100

# %%
df['MBU_done_%'] = x

# %%
df
# Out:
#                       District Name District Code Academic Year Total Student  \
# 5                             BALOD          2222       2026-27        124282
# 7                       BALODABAZAR          2224       2026-27        215368
# 9                         BALRAMPUR          2226       2026-27        152725
# 11                           BASTER          2215       2026-27        145538
# 13                         BEMETARA          2223       2026-27        158754
# 14                          BIJAPUR          2220       2026-27         57176
# 16                         BILASPUR          2207       2026-27        344923
# 18                        DANTEWADA          2216       2026-27         49385
# 20                         DHAMTARI          2213       2026-27        123702
# 22                             DURG          2210       2026-27        272338
# 24                        GARIABAND          2225       2026-27         92014
# ...

# %%
df['MBU_done_%'] = df['MBU_done_%'].astype('float').round(2)

# %%
df.to_csv("MBU_data.csv")
